# %% [markdown]
# # 02. Model Benchmarking, Holdout Evaluation & Explainability
# Analysis of 5 clinical classifiers, holdout confusion matrix, per-class performance, and SHAP patient explanations.

# %%
import sys
sys.path.insert(0, "..")
import json
import pandas as pd
from config.config import ARTIFACTS_DIR

# 1. Model Comparison Table
comp_df = pd.read_csv(ARTIFACTS_DIR / "model_comparison.csv")
comp_df

# %% [markdown]
# ## Feature Importance (Permutation vs. Gini)

# %%
imp_df = pd.read_csv(ARTIFACTS_DIR / "feature_importance.csv")
imp_df.head(10)
